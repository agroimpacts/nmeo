# %%
import arablepy
import pandas as pd

client = arablepy.ArableClient()

# %%
  #  client.connect(email='lestes@clarku.edu', password='rollinghills88')
#client.connect(email='caylor@ucsb.edu', password='greenresearch11')
client.connect(email='lestes@clarku.edu', password='rollinghills88')

# %%
## types of data sets
## we will mostly use "daily"
client.schema(df=True)
# Out:
#                                     0
# 0                             aux_raw
# 1                               daily
# 2                              health
# 3                              hourly
# 4            irrigation_runtime_daily
# 5           irrigation_runtime_hourly
# 6                        local_hourly
# 7  location_irrigation_forecast_daily
# 8                        sentek_daily
# 9                       sentek_hourly

# %%
## columns in "daily" data set
client.schema('hourly', df=True)
# Out:
#        column_name                 data_type  \
# 0             b1dw                      real
# 1             b1uw                      real
# 2             b2dw                      real
# 3             b2uw                      real
# 4             b3dw                      real
# 5             b3uw                      real
# 6             b4dw                      real
# 7             b4uw                      real
# 8             b5dw                      real
# 9             b5uw                      real
# 10            b6dw                      real
# 11            b6uw                      real
# 12            b7dw                      real
# 13            b7uw                      real
# 14          device                      text
# 15              ea          double precision
# 16              et                      real
# 17             etc                      real
# 18      et_version         character varying
# 19             lat                      real
# 20             lfw                      real
# 21        location                      text
# 22            long                      real
# 23     low_quality                   boolean
# 24            lwdw                      real
# 25            lwuw                      real
# 26            maxt                      real
# 27        max_tdew          double precision
# 28          min_rh                      real
# 29            mint                      real
# 30               p                      real
# 31           pardw                      real
# 32           paruw                      real
# 33           prate                      real
# 34          precip                      real
# 35              rh                      real
# 36      rh_at_maxt                      real
# 37      sample_pct          double precision
# 38             slp          double precision
# 39            swdw                      real
# 40            swuw                      real
# 41          tabove                      real
# 42            tair                      real
# 43          tbelow                      real
# 44            tdew                      real
# 45            time  timestamp with time zone
# 46             vpd          double precision
# 47  wind_direction         character varying
# 48    wind_heading                      real
# 49      wind_speed                      real
# 50  wind_speed_max                      real
# 51  wind_speed_min                      real
#
#                                           description
# 0     Spectrometer data bands 1-7 downwelling (W/m^2)
# 1       Spectrometer data bands 1-7 upwelling (W/m^2)
# 2     Spectrometer data bands 1-7 downwelling (W/m^2)
# 3       Spectrometer data bands 1-7 upwelling (W/m^2)
# 4     Spectrometer data bands 1-7 downwelling (W/m^2)
# 5       Spectrometer data bands 1-7 upwelling (W/m^2)
# 6     Spectrometer data bands 1-7 downwelling (W/m^2)
# 7       Spectrometer data bands 1-7 upwelling (W/m^2)
# 8     Spectrometer data bands 1-7 downwelling (W/m^2)
# 9       Spectrometer data bands 1-7 upwelling (W/m^2)
# 10    Spectrometer data bands 1-7 downwelling (W/m^2)
# 11      Spectrometer data bands 1-7 upwelling (W/m^2)
# 12    Spectrometer data bands 1-7 downwelling (W/m^2)
# 13      Spectrometer data bands 1-7 upwelling (W/m^2)
# 14                   Arable device ID (e.g., A000176)
# 15                  Actual Water Vapor Pressure (kPa)
# 16                      Evapotranspiration (ETo) (mm)
# 17                       Crop Evapotranspiration (mm)
# 18                                               None
# 19                          Latitude (decimal degree)
# 20                                 Leaf wetness (min)
# 21                         Location ID (24-digit hex)
# 22                         Longitude (decimal degree)
# 23                          True for Low Data Quality
# 24          Longwave downwelling, hourly mean (W/m^2)
# 25            Longwave upwelling, hourly mean (W/m^2)
# 26  The maximum air temperature experienced during...
# 27  The maximum dew point temperature (C) in the hour
# 28  The minimum relative humidity (between 0 and 1...
# 29  The minimum air temperature experienced during...
# 30                                     Pressure (kPa)
# 31  Photosynthetically Active Radiation downwellin...
# 32  Photosynthetically Active Radiation upwelling ...
# 33                          Precipitation rate (mm/h)
# 34                           Precipitation total (mm)
# 35                Relative humidity (between 0 and 1)
# 36  The Relative humidity (between 0 and 1) when a...
# 37                         Aggregation Sample Percent
# 38                           Sea Level Pressure (kPa)
# 39        Short wave downwelling, hourly mean (W/m^2)
# 40          Short wave upwelling, hourly mean (W/m^2)
# 41                                Sky temperature (C)
# 42                                Air temperature (C)
# 43                        Leaf/ground temperature (C)
# 44                                Dew temperature (C)
# 45                                           UTC time
# 46                       Vapor Pressure Deficit (kPa)
# 47                   Wind direction; N, NNE, NE, etc.
# 48                              Wind heading, degrees
# 49                          Wind speed, stored as m/s
# 50                      Max wind speed, stored as m/s
# 51                      Min wind speed, stored as m/s

# %%
#  a =   client.data('daily', devices='A000680', start_time='2020-01-01', end_time='2020-07-07T00:00:00Z', df=False)
# print(a)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from datetime import date
today = date.today()
d1 = today.strftime("%Y-%m-%d")
print("today's date ", d1)
# Out:
# today's date  2021-04-20

# %%
df = client.data('daily', devices= ['A000680'], start_time='2017-01-01', end_time= d1)
print(df)
# Out:
#        ea  crop_water_demand  sunshine_duration                  time    dli  \
# 0     NaN                NaN                NaN  2018-06-09T00:00:00Z  34.82
# 1     NaN                NaN                NaN  2018-06-10T00:00:00Z  24.48
# 2     NaN                NaN                NaN  2018-06-11T00:00:00Z  31.68
# 3     NaN                NaN                NaN  2018-06-12T00:00:00Z  39.85
# 4     NaN                NaN                NaN  2018-06-13T00:00:00Z  13.04
# ..    ...                ...                ...                   ...    ...
# 270  1.43               -0.9               10.0  2020-09-07T00:00:00Z  20.80
# 271  1.68               -1.0                9.4  2020-09-08T00:00:00Z  19.62
# 272  1.73               -0.6                8.8  2020-09-09T00:00:00Z  15.75
# 273  1.47                6.7                6.9  2020-09-10T00:00:00Z  11.22
# 274  2.15                NaN                0.2  2020-09-11T00:00:00Z   2.78
#
#      prate wind_speed    slp   et  vpd  ...  lfairdelta  rh_at_maxt  \
# 0      NaN       None  101.8  5.2  NaN  ...         8.5         NaN
# 1      NaN       None  101.7  3.8  NaN  ...         6.0         NaN
# 2      NaN       None  101.7  4.3  NaN  ...        11.0         NaN
# 3      0.0       None  102.1  5.2  NaN  ...        10.0         NaN
# 4      0.2       None  101.4  1.1  NaN  ...         4.5         NaN
# ..     ...        ...    ...  ...  ...  ...         ...         ...
# 270    0.0       None  102.0  2.0  0.5  ...         7.4        0.55
# 271    0.0       None  102.2  2.1  0.6  ...         6.3        0.52
# 272    0.0       None  102.6  1.8  0.6  ...         6.8        0.51
# 273    6.8       None  102.4  1.0  0.2  ...         5.6        0.83
# 274    1.2       None  102.1  0.1  0.2  ...         NaN        0.93
#
#      wind_speed_max  lfw  wind_direction  mint precip     long  \
# 0              None  NaN            None  15.1    NaN -71.8065
# 1              None  NaN            None  14.5    NaN -71.8065
# 2              None  NaN            None  11.5    NaN -71.8065
# 3              None  NaN            None  10.0    0.0 -71.8065
# 4              None  NaN            None  12.7    0.2 -71.8065
# ..              ...  ...             ...   ...    ...      ...
# 270            None  0.0            None  10.3    0.0 -71.8065
# 271            None  2.0            None  11.5    0.0 -71.8065
# 272            None  5.0            None  12.3    0.0 -71.8065
# 273            None  4.0            None  13.8    6.8 -71.8065
# 274            None  2.0            None   9.1    1.2 -71.8065
#
#     gdd_cumulative_source  tdew_at_mint
# 0                    None           NaN
# 1                    None           NaN
# 2                    None           NaN
# 3                    None           NaN
# 4                    None           NaN
# ..                    ...           ...
# 270                  None          14.8
# 271                  None          15.5
# 272                  None          17.2
# 273                  None          17.1
# 274                  None          15.6
#
# [275 rows x 45 columns]

# %%
## save data frame to csv
fname = "./" + "A000680_daily.csv"
df.to_csv(fname)

# %%
from datetime import date
today = date.today()
d1 = today.strftime("%Y-%m-%d")
print(d1)


devices=['A000667', 'A000680', 'A000671']   # new


for device in devices: 
    device_list = [device]
    print(device)
    df = client.data('hourly', devices=device_list,start_time='2017-01-01', end_time= d1)
    fname = './' + device + '_hourly.csv'
    df.to_csv(fname)
    df = client.data('daily', devices=device_list ,start_time='2017-10-01', end_time=d1)
    fname = './' + device + '_daily.csv'
    df.to_csv(fname)

df
# Out:
# 2021-04-20
# A000667
# A000680
# A000671
#      meant  ndvi  precip  lfairdelta             mint_time wind_speed_max  \
# 0     19.7  0.16     NaN         7.7                  None           None
# 1     17.6  0.16     0.0         5.7                  None           None
# 2     15.0  0.16     0.0        10.8                  None           None
# 3     15.1  0.16     1.3         9.3                  None           None
# 4     16.5  0.17     0.3         3.9                  None           None
# ..     ...   ...     ...         ...                   ...            ...
# 272   18.7  0.58     0.0         5.9  2020-09-07T05:48:28Z           None
# 273   20.7  0.57     0.0         5.9  2020-09-08T06:53:12Z           None
# 274   20.4  0.55     0.0         5.6  2020-09-09T01:56:47Z           None
# 275   21.5  0.55     5.9         4.0  2020-09-10T02:36:28Z           None
# 276   21.4 -0.29     9.8         4.9  2020-09-11T11:32:49Z           None
#
#      mean_tbelow    ea gdd_cumulative_source    kc  ...             maxt_time  \
# 0            NaN   NaN                  None  0.07  ...                  None
# 1            NaN   NaN                  None  0.06  ...                  None
# 2            NaN   NaN                  None  0.07  ...                  None
# 3            NaN   NaN                  None  0.07  ...                  None
# 4            NaN   NaN                  None  0.08  ...                  None
# ..           ...   ...                   ...   ...  ...                   ...
# 272         21.9  1.87                  None  0.67  ...  2020-09-07T16:10:19Z
# 273         23.6  1.86                  None  0.66  ...  2020-09-08T16:29:57Z
# 274         23.6  2.05                  None  0.64  ...  2020-09-09T13:08:55Z
# 275         23.7  2.07                  None  0.63  ...  2020-09-10T16:29:03Z
# 276         23.9  2.59                  None  0.00  ...  2020-09-11T13:53:17Z
#
#     tdew_at_mint  wind_heading   lfw    cl   device  low_quality  tdew  \
# 0            NaN          None   NaN  0.33  A000671         None   NaN
# 1            NaN          None   NaN  0.33  A000671         None   NaN
# 2            NaN          None   NaN  0.34  A000671         None   NaN
# 3            NaN          None   NaN  0.34  A000671         None   NaN
# 4            NaN          None   NaN  0.36  A000671         None   NaN
# ..           ...           ...   ...   ...      ...          ...   ...
# 272         15.6          None  10.0  3.92  A000671        False  15.4
# 273         17.1          None  12.0  3.79  A000671        False  17.8
# 274         18.5          None  10.0  3.71  A000671        False  17.6
# 275         18.6          None  22.0  3.80  A000671        False  21.5
# 276         17.4          None  17.0 -0.29  A000671        False  18.8
#
#      gdd_source    dli
# 0          None  35.07
# 1          None  24.51
# 2          None  31.44
# 3          None  39.21
# 4          None  13.74
# ..          ...    ...
# 272        None  17.19
# 273        None  16.36
# 274        None  11.90
# 275        None   7.08
# 276        None   1.21
#
# [277 rows x 45 columns]

# %%
# Out:
#                                     0
# 0                             aux_raw
# 1                               daily
# 2                              health
# 3                              hourly
# 4            irrigation_runtime_daily
# 5           irrigation_runtime_hourly
# 6                        local_hourly
# 7  location_irrigation_forecast_daily
# 8                        sentek_daily
# 9                       sentek_hourly
